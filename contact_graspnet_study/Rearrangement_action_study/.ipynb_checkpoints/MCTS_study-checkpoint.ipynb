# %%
from pytamp.benchmark import Rearrange1
from pytamp.utils.making_scene_utils import load_mesh, get_obj_name, Make_Scene
from pykin.utils.mesh_utils import get_object_mesh, get_object_mesh_acronym
from pykin.utils import plot_utils as p_utils

import easydict
from pytamp.action.rearrangement import RearrangementAction
from pytamp.search.mcts_for_rearragement import MCTS_rearrangement
import numpy as np

def custom_parser():
    # object는 parser.add_argument( ~ , nargs="+") , nargs="+" 때문에 list로 arg 셋팅함
    args = easydict.EasyDict({
        "objects" : [
                    # "/home/juju/contact_graspnet/acronym/grasps/Candle_b94fcdffbd1befa57f5e345e9a3e5d44_0.012740999337464653.h5", 
                    # "/home/juju/contact_graspnet/acronym/grasps/Canister_714320da4aafcb4a47be2353d2b2403b_0.00023318612778400807.h5", 
                    # "/home/juju/contact_graspnet/acronym/grasps/Bowl_2efc35a3625fa50961a9876fa6384765_0.012449533111417973.h5",
                    # "/home/juju/contact_graspnet/acronym/grasps/Xbox360_435f39e98d2260f0d6e21b8525c3f8bb_0.002061950217848804.h5"
                    ],

        "support" : "/home/juju/contact_graspnet/acronym/grasps/3Shelves_29b66fc9db2f1558e0e89fd83955713c_0.0025867867973150068.h5",
        "num_grasps" : 5,
        "mesh_root" : '/home/juju/contact_graspnet/acronym/',
        "support_scale" : 0.025,

        "budgets" : 100,
        "max_depth" :  16,
        "seed" : 2,
        "algo" : "bai_perturb",
        "debug_mode" : False,

    })
    return args

def make_scene_():

    
    obj_dict = {}

    args = custom_parser()

    args.objects.append('ben_cube.stl')
    args.objects.append('bottle.stl')
    args.objects.append('bottle.stl')
    args.objects.append('ben_cube.stl')

    obj_dict = {}
    object_meshes=[]
    object_names=[]

    for o in args.objects:
        if '.h5' in o:
            object_meshes.append(load_mesh(o, mesh_root_dir=args.mesh_root))
            object_names.append(get_obj_name(obj_dict, o))
        if '.stl' in o:
            if 'cube' in o:
#                 object_meshes.append(get_object_mesh(o, 0.075))
                object_meshes.append(get_object_mesh(o, 0.075))
                object_names.append(get_obj_name(obj_dict, o))
            else:
                object_meshes.append(get_object_mesh(o))
                object_names.append(get_obj_name(obj_dict, o))

    # for PYTAMP 
    support_mesh = get_object_mesh("ben_table.stl", scale=[1.0, 1.5, 1.0])
    init_scene = Make_Scene.random_arrangement(object_names, object_meshes, support_mesh)
    goal_scene = Make_Scene.random_arrangement(object_names, object_meshes, support_mesh, for_goal_scene=True)
    rearrangement_scene = Rearrange1('doosan', object_names, init_scene, goal_scene, is_pyplot=False)

    return rearrangement_scene

args = custom_parser()

rearrangement1 = make_scene_()

final_level_1_values = []
final_level_2_values = []
final_optimal_nodes = []
final_pnp_all_joint_paths = []
final_pick_all_objects = []
final_place_all_object_poses = []

# final_optimal_trees = []
c_list = 10 ** np.linspace(-2, 2.0, 1)
# Out:
# *********************** Logical States ***********************
# OrderedDict([('ben_cube0',
#               {'on': Object(name=table, pos=[ 1.    -0.6    0.043])}),
#              ('bottle0',
#               {'on': Object(name=table, pos=[ 1.    -0.6    0.043])}),
#              ('bottle1',
#               {'on': Object(name=table, pos=[ 1.    -0.6    0.043])}),
#              ('ben_cube1',
#               {'on': Object(name=table, pos=[ 1.    -0.6    0.043])}),
#              ('table',
#               {'static': True,
#                'support': [Object(name=ben_cube0, pos=[0.48199375 0.15595815 0.84779998]),
#                            Object(name=bottle0, pos=[0.41530036 0.12046782 0.83593754]),
#                            Object(name=bottle1, pos=[0.51208162 0.29793956 0.83593754]),
#                            Object(name=ben_cube1, pos=[ 0.50399246 -0.25118311  0.84779998])]}),
#              ('robotiq140_gripper', {'holding': None})])
# ***************************************************************
#
# *********************** Logical States ***********************
# OrderedDict([('ben_cube0',
#               {'on': Object(name=table, pos=[ 1.    -0.6    0.043])}),
#              ('bottle0',
#               {'on': Object(name=table, pos=[ 1.    -0.6    0.043])}),
#              ('bottle1',
#               {'on': Object(name=table, pos=[ 1.    -0.6    0.043])}),
#              ('ben_cube1',
#               {'on': Object(name=table, pos=[ 1.    -0.6    0.043])}),
#              ('table',
#               {'static': True,
#                'support': [Object(name=ben_cube0, pos=[ 0.92480878 -0.51629904  0.84779998]),
#                            Object(name=bottle0, pos=[0.81070429 0.49155963 0.87515735]),
#                            Object(name=bottle1, pos=[ 0.88946181 -0.45767339  0.87515735]),
#                            Object(name=ben_cube1, pos=[0.94914928 0.30355697 0.84779998])]}),
#              ('robotiq140_gripper', {'holding': None})])
# ***************************************************************

# %%
c = 1
mcts = MCTS_rearrangement(
        scene_mngr=rearrangement1.scene_mngr,
        sampling_method=args.algo,
        budgets=args.budgets,
        max_depth=args.max_depth,
        c=c,
        debug_mode=args.debug_mode,
    )

mcts.only_optimize_1 = True

# %%
mcts.do_planning_rearrange(0)
# Out:
# =========== Search iteration : 1 ===========
# [Action] Rearr bottle0
# {'type': 'rearr', 'rearr_obj_name': 'bottle0', 'rearr_poses': [{'bottle0': array([[ 0.42057919,  0.90725583,  0.        ,  0.81070429],
#        [-0.90725583,  0.42057919,  0.        ,  0.49155963],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(0) -> A(2) -> S'(5) Reward : -1
# [Action] Rearr bottle0
# {'type': 'rearr', 'rearr_obj_name': 'bottle0', 'rearr_poses': [{'bottle0': array([[ 0.42057919,  0.90725583,  0.        ,  0.81070429],
#        [-0.90725583,  0.42057919,  0.        ,  0.49155963],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(5) -> A(7) -> S'(10) Reward : -1
# [Action] Rearr bottle1
# {'type': 'rearr', 'rearr_obj_name': 'bottle1', 'rearr_poses': [{'bottle1': array([[ 0.27115718, -0.96253508,  0.        ,  0.88946181],
#        [ 0.96253508,  0.27115718,  0.        , -0.45767339],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(10) -> A(13) -> S'(15) Reward : -1
# [Action] Rearr ben_cube1
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube1', 'rearr_poses': [{'ben_cube1': array([[-0.94482806,  0.32756669,  0.        ,  0.94914928],
#        [-0.32756669, -0.94482806,  0.        ,  0.30355697],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(15) -> A(19) -> S'(20) Reward : -1
# [Action] Rearr ben_cube1
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube1', 'rearr_poses': [{'ben_cube1': array([[-0.94482806,  0.32756669,  0.        ,  0.94914928],
#        [-0.32756669, -0.94482806,  0.        ,  0.30355697],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(20) -> A(24) -> S'(25) Reward : -1
# [Action] Rearr ben_cube0
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube0', 'rearr_poses': [{'ben_cube0': array([[ 0.91009061, -0.41440932,  0.        ,  0.92480878],
#        [ 0.41440932,  0.91009061,  0.        , -0.51629904],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(25) -> A(26) -> S'(30) Reward : -1
# [Action] Rearr ben_cube0
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube0', 'rearr_poses': [{'ben_cube0': array([[ 0.91009061, -0.41440932,  0.        ,  0.92480878],
#        [ 0.41440932,  0.91009061,  0.        , -0.51629904],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(30) -> A(31) -> S'(35) Reward : -1
# [Action] Rearr bottle1
# {'type': 'rearr', 'rearr_obj_name': 'bottle1', 'rearr_poses': [{'bottle1': array([[ 0.27115718, -0.96253508,  0.        ,  0.88946181],
#        [ 0.96253508,  0.27115718,  0.        , -0.45767339],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(35) -> A(38) -> S'(40) Reward : -1
# [Action] Rearr bottle1
# {'type': 'rearr', 'rearr_obj_name': 'bottle1', 'rearr_poses': [{'bottle1': array([[ 0.27115718, -0.96253508,  0.        ,  0.88946181],
#        [ 0.96253508,  0.27115718,  0.        , -0.45767339],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(40) -> A(43) -> S'(45) Reward : -1
# [Action] Rearr ben_cube0
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube0', 'rearr_poses': [{'ben_cube0': array([[ 0.91009061, -0.41440932,  0.        ,  0.92480878],
#        [ 0.41440932,  0.91009061,  0.        , -0.51629904],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(45) -> A(46) -> S'(50) Reward : -1
# [Action] Rearr ben_cube1
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube1', 'rearr_poses': [{'ben_cube1': array([[-0.94482806,  0.32756669,  0.        ,  0.94914928],
#        [-0.32756669, -0.94482806,  0.        ,  0.30355697],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(50) -> A(54) -> S'(55) Reward : -1
# [Action] Rearr ben_cube0
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube0', 'rearr_poses': [{'ben_cube0': array([[ 0.91009061, -0.41440932,  0.        ,  0.92480878],
#        [ 0.41440932,  0.91009061,  0.        , -0.51629904],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(55) -> A(56) -> S'(60) Reward : -1
# [Action] Rearr bottle0
# {'type': 'rearr', 'rearr_obj_name': 'bottle0', 'rearr_poses': [{'bottle0': array([[ 0.42057919,  0.90725583,  0.        ,  0.81070429],
#        [-0.90725583,  0.42057919,  0.        ,  0.49155963],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(60) -> A(62) -> S'(65) Reward : -1
# [Action] Rearr ben_cube0
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube0', 'rearr_poses': [{'ben_cube0': array([[ 0.91009061, -0.41440932,  0.        ,  0.92480878],
#        [ 0.41440932,  0.91009061,  0.        , -0.51629904],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(65) -> A(66) -> S'(70) Reward : -1
# [Action] Rearr ben_cube1
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube1', 'rearr_poses': [{'ben_cube1': array([[-0.94482806,  0.32756669,  0.        ,  0.94914928],
#        [-0.32756669, -0.94482806,  0.        ,  0.30355697],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(70) -> A(74) -> S'(75) Reward : -1
# [Action] Rearr ben_cube1
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube1', 'rearr_poses': [{'ben_cube1': array([[-0.94482806,  0.32756669,  0.        ,  0.94914928],
#        [-0.32756669, -0.94482806,  0.        ,  0.30355697],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(75) -> A(79) -> S'(80) Reward : -1
# Exceeded the maximum depth!!

# %%
mcts.do_planning_rearrange(1)
# Out:
# =========== Search iteration : 2 ===========
# [Action] Rearr ben_cube0
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube0', 'rearr_poses': [{'ben_cube0': array([[ 0.91009061, -0.41440932,  0.        ,  0.92480878],
#        [ 0.41440932,  0.91009061,  0.        , -0.51629904],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(0) -> A(1) -> S'(157) Reward : -1
# [Action] Rearr bottle1
# {'type': 'rearr', 'rearr_obj_name': 'bottle1', 'rearr_poses': [{'bottle1': array([[ 0.27115718, -0.96253508,  0.        ,  0.88946181],
#        [ 0.96253508,  0.27115718,  0.        , -0.45767339],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(157) -> A(160) -> S'(162) Reward : -1
# [Action] Rearr ben_cube1
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube1', 'rearr_poses': [{'ben_cube1': array([[-0.94482806,  0.32756669,  0.        ,  0.94914928],
#        [-0.32756669, -0.94482806,  0.        ,  0.30355697],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(162) -> A(166) -> S'(167) Reward : -1
# [Action] Rearr ben_cube1
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube1', 'rearr_poses': [{'ben_cube1': array([[-0.94482806,  0.32756669,  0.        ,  0.94914928],
#        [-0.32756669, -0.94482806,  0.        ,  0.30355697],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(167) -> A(171) -> S'(172) Reward : -1
# [Action] Rearr ben_cube1
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube1', 'rearr_poses': [{'ben_cube1': array([[-0.94482806,  0.32756669,  0.        ,  0.94914928],
#        [-0.32756669, -0.94482806,  0.        ,  0.30355697],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(172) -> A(176) -> S'(177) Reward : -1
# [Action] Rearr bottle1
# {'type': 'rearr', 'rearr_obj_name': 'bottle1', 'rearr_poses': [{'bottle1': array([[ 0.27115718, -0.96253508,  0.        ,  0.88946181],
#        [ 0.96253508,  0.27115718,  0.        , -0.45767339],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(177) -> A(180) -> S'(182) Reward : -1
# [Action] Rearr bottle0
# {'type': 'rearr', 'rearr_obj_name': 'bottle0', 'rearr_poses': [{'bottle0': array([[ 0.42057919,  0.90725583,  0.        ,  0.81070429],
#        [-0.90725583,  0.42057919,  0.        ,  0.49155963],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(182) -> A(184) -> S'(187) Reward : -1
# [Action] Rearr bottle1
# {'type': 'rearr', 'rearr_obj_name': 'bottle1', 'rearr_poses': [{'bottle1': array([[ 0.27115718, -0.96253508,  0.        ,  0.88946181],
#        [ 0.96253508,  0.27115718,  0.        , -0.45767339],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(187) -> A(190) -> S'(192) Reward : -1
# [Action] Rearr bottle1
# {'type': 'rearr', 'rearr_obj_name': 'bottle1', 'rearr_poses': [{'bottle1': array([[ 0.27115718, -0.96253508,  0.        ,  0.88946181],
#        [ 0.96253508,  0.27115718,  0.        , -0.45767339],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(192) -> A(195) -> S'(197) Reward : -1
# [Action] Rearr bottle1
# {'type': 'rearr', 'rearr_obj_name': 'bottle1', 'rearr_poses': [{'bottle1': array([[ 0.27115718, -0.96253508,  0.        ,  0.88946181],
#        [ 0.96253508,  0.27115718,  0.        , -0.45767339],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(197) -> A(200) -> S'(202) Reward : -1
# [Action] Rearr ben_cube1
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube1', 'rearr_poses': [{'ben_cube1': array([[-0.94482806,  0.32756669,  0.        ,  0.94914928],
#        [-0.32756669, -0.94482806,  0.        ,  0.30355697],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(202) -> A(206) -> S'(207) Reward : -1
# [Action] Rearr ben_cube0
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube0', 'rearr_poses': [{'ben_cube0': array([[ 0.91009061, -0.41440932,  0.        ,  0.92480878],
#        [ 0.41440932,  0.91009061,  0.        , -0.51629904],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(207) -> A(208) -> S'(212) Reward : -1
# [Action] Rearr ben_cube1
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube1', 'rearr_poses': [{'ben_cube1': array([[-0.94482806,  0.32756669,  0.        ,  0.94914928],
#        [-0.32756669, -0.94482806,  0.        ,  0.30355697],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(212) -> A(216) -> S'(217) Reward : -1
# [Action] Rearr bottle1
# {'type': 'rearr', 'rearr_obj_name': 'bottle1', 'rearr_poses': [{'bottle1': array([[ 0.27115718, -0.96253508,  0.        ,  0.88946181],
#        [ 0.96253508,  0.27115718,  0.        , -0.45767339],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(217) -> A(220) -> S'(222) Reward : -1
# [Action] Rearr bottle1
# {'type': 'rearr', 'rearr_obj_name': 'bottle1', 'rearr_poses': [{'bottle1': array([[ 0.27115718, -0.96253508,  0.        ,  0.88946181],
#        [ 0.96253508,  0.27115718,  0.        , -0.45767339],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(222) -> A(225) -> S'(227) Reward : -1
# [Action] Rearr ben_cube0
# {'type': 'rearr', 'rearr_obj_name': 'ben_cube0', 'rearr_poses': [{'ben_cube0': array([[ 0.91009061, -0.41440932,  0.        ,  0.92480878],
#        [ 0.41440932,  0.91009061,  0.        , -0.51629904],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]}
# [Reward] S(227) -> A(228) -> S'(232) Reward : -1
# Exceeded the maximum depth!!

# %%
mcts.tree.nodes[64]
# Out:
# {'depth': 13,
#  'state': <pytamp.scene.scene.Scene at 0x7f3ae5a72370>,
#  'action': {'type': 'rearr',
#   'rearr_obj_name': 'ben_cube1',
#   'rearr_poses': [{'ben_cube1': array([[-0.94482806,  0.32756669,  0.        ,  0.94914928],
#            [-0.32756669, -0.94482806,  0.        ,  0.30355697],
#            [ 0.        ,  0.        ,  1.        ,  0.84779998],
#            [ 0.        ,  0.        ,  0.        ,  1.        ]])}]},
#  'value': -inf,
#  'value_history': [],
#  'visit': 0,
#  'number': 64,
#  'type': 'action',
#  'joints': [],
#  'level1': False,
#  'level2': False,
#  'success': False,
#  'cost': 0,
#  'test': ()}

# %%
mcts.tree.nodes[64]['state'].objs['ben_cube1'].h_mat
# Out:
# array([[-0.94482806,  0.32756669,  0.        ,  0.94914928],
#        [-0.32756669, -0.94482806,  0.        ,  0.30355697],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])

# %%
mcts.visualize_tree("Success nodes", mcts.tree)

# %%
from pykin.utils import transform_utils as t_utils

mcts.tree.nodes[1]['state'].objs['ben_cube0'].h_mat.dot\
(t_utils.get_inverse_homogeneous(mcts.scene_mngr.scene.goal_object_poses['ben_cube0']))
# Out:
# array([[ 0.37169005,  0.38907612,  0.84289162, -0.55528713],
#        [ 0.58224141,  0.60947618, -0.53808338,  0.37844068],
#        [-0.72307776,  0.69076664,  0.        ,  0.87515036],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])

# %%
mcts.tree.nodes[1]['state'].objs['ben_cube0'].h_mat
# Out:
# array([[ 0.        , -0.53808338,  0.84289162,  0.50850984],
#        [ 0.        , -0.84289162, -0.53808338,  0.46925482],
#        [ 1.        ,  0.        ,  0.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])

# %%
from pytamp.search.node_data import NodeData

mcts.tree.nodes.get(1).get(NodeData.ACTION)
# Out:
# {'ben_cube0': array([[-0.93456085,  0.35580335,  0.        ,  0.95147945],
#         [-0.35580335, -0.93456085,  0.        , -0.57699393],
#         [ 0.        ,  0.        ,  1.        ,  0.84779998],
#         [ 0.        ,  0.        ,  0.        ,  1.        ]])}

# %%
list(mcts.rearr_action.get_possible_actions_level_1(mcts.tree.nodes[0]['state']))
# Out:
# [{'ben_cube0': array([[-0.90450956,  0.42645334,  0.        ,  0.39838827],
#          [-0.42645334, -0.90450956,  0.        , -0.03850557],
#          [ 0.        ,  0.        ,  1.        ,  0.84779998],
#          [ 0.        ,  0.        ,  0.        ,  1.        ]])},
#  {'bottle0': array([[-0.9895741 , -0.14402462,  0.        ,  0.78862205],
#          [ 0.14402462, -0.9895741 ,  0.        ,  0.07789252],
#          [ 0.        ,  0.        ,  1.        ,  0.87515735],
#          [ 0.        ,  0.        ,  0.        ,  1.        ]])},
#  {'bottle1': array([[-0.17594032, -0.98440084,  0.        ,  0.52446574],
#          [ 0.98440084, -0.17594032,  0.        , -0.00533912],
#          [ 0.        ,  0.        ,  1.        ,  0.87515735],
#          [ 0.        ,  0.        ,  0.        ,  1.        ]])},
#  {'ben_cube1': None}]

# %%
mcts._level_wise_1_optimize_rearr
